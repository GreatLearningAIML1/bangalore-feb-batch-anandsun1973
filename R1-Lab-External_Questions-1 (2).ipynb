# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import numpy as np
import pandas as pd
import scipy as sc
import matplotlib as mp
iris = pd.read_csv('iris.csv')

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris.index=iris.iloc[:,0]

# %%
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.iloc[:,2]
# Out:
# Sepal Length (in cm)
# 5.1    1.4
# 4.9    1.4
# 4.7    1.3
# 4.6    1.5
# 5.0    1.4
# 5.4    1.7
# 4.6    1.4
# 5.0    1.5
# 4.4    1.4
# 4.9    1.5
# 5.4    1.5
# 4.8    1.6
# 4.8    1.4
# 4.3    1.1
# 5.8    1.2
# 5.7    1.5
# 5.4    1.3
# 5.1    1.4
# 5.7    1.7
# 5.1    1.5
# 5.4    1.7
# 5.1    1.5
# 4.6    1.0
# 5.1    1.7
# 4.8    1.9
# 5.0    1.6
# 5.0    1.6
# 5.2    1.5
# 5.2    1.4
# 4.7    1.6
#       ...
# 6.9    5.7
# 5.6    4.9
# 7.7    6.7
# 6.3    4.9
# 6.7    5.7
# 7.2    6.0
# 6.2    4.8
# 6.1    4.9
# 6.4    5.6
# 7.2    5.8
# 7.4    6.1
# 7.9    6.4
# 6.4    5.6
# 6.3    5.1
# 6.1    5.6
# 7.7    6.1
# 6.3    5.6
# 6.4    5.5
# 6.0    4.8
# 6.9    5.4
# 6.7    5.6
# 6.9    5.1
# 5.8    5.1
# 6.8    5.9
# 6.7    5.7
# 6.7    5.2
# 6.3    5.0
# 6.5    5.2
# 6.2    5.4
# 5.9    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.iloc[0:10,1]
# Out:
# Sepal Length (in cm)
# 5.1    3.5
# 4.9    3.0
# 4.7    3.2
# 4.6    3.1
# 5.0    3.6
# 5.4    3.9
# 4.6    3.4
# 5.0    3.4
# 4.4    2.9
# 4.9    3.1
# Name: Sepal Width in (cm), dtype: float64

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
iris.loc[iris['Class'].isin(["Iris-setosa"])]
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
# 5.4                                    5.4                  3.7
# 4.8                                    4.8                  3.4
# 4.8                                    4.8                  3.0
# 4.3                                    4.3                  3.0
# 5.8                                    5.8                  4.0
# 5.7                                    5.7                  4.4
# 5.4                                    5.4                  3.9
# 5.1                                    5.1                  3.5
# 5.7                                    5.7                  3.8
# 5.1                                    5.1                  3.8
# 5.4                                    5.4                  3.4
# 5.1                                    5.1                  3.7
# 4.6                                    4.6                  3.6
# 5.1                                    5.1                  3.3
# 4.8                                    4.8                  3.4
# 5.0                                    5.0                  3.0
# 5.0                                    5.0                  3.4
# 5.2                                    5.2                  3.5
# 5.2                                    5.2                  3.4
# 4.7                                    4.7                  3.2
# 4.8                                    4.8                  3.1
# 5.4                                    5.4                  3.4
# 5.2                                    5.2                  4.1
# 5.5                                    5.5                  4.2
# 4.9                                    4.9                  3.1
# 5.0                                    5.0                  3.2
# 5.5                                    5.5                  3.5
# 4.9                                    4.9                  3.1
# 4.4                                    4.4                  3.0
# 5.1                                    5.1                  3.4
# 5.0                                    5.0                  3.5
# 4.5                                    4.5                  2.3
# 4.4                                    4.4                  3.2
# 5.0                                    5.0                  3.5
# 5.1                                    5.1                  3.8
# 4.8                                    4.8                  3.0
# 5.1                                    5.1                  3.8
# 4.6                                    4.6                  3.2
# 5.3                                    5.3                  3.7
# 5.0                                    5.0                  3.3
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa
# 5.4                                    1.7                  0.4  Iris-setosa
# 4.6                                    1.4                  0.3  Iris-setosa
# 5.0                                    1.5                  0.2  Iris-setosa
# 4.4                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.5                  0.1  Iris-setosa
# 5.4                                    1.5                  0.2  Iris-setosa
# 4.8                                    1.6                  0.2  Iris-setosa
# 4.8                                    1.4                  0.1  Iris-setosa
# 4.3                                    1.1                  0.1  Iris-setosa
# 5.8                                    1.2                  0.2  Iris-setosa
# 5.7                                    1.5                  0.4  Iris-setosa
# 5.4                                    1.3                  0.4  Iris-setosa
# 5.1                                    1.4                  0.3  Iris-setosa
# 5.7                                    1.7                  0.3  Iris-setosa
# 5.1                                    1.5                  0.3  Iris-setosa
# 5.4                                    1.7                  0.2  Iris-setosa
# 5.1                                    1.5                  0.4  Iris-setosa
# 4.6                                    1.0                  0.2  Iris-setosa
# 5.1                                    1.7                  0.5  Iris-setosa
# 4.8                                    1.9                  0.2  Iris-setosa
# 5.0                                    1.6                  0.2  Iris-setosa
# 5.0                                    1.6                  0.4  Iris-setosa
# 5.2                                    1.5                  0.2  Iris-setosa
# 5.2                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.6                  0.2  Iris-setosa
# 4.8                                    1.6                  0.2  Iris-setosa
# 5.4                                    1.5                  0.4  Iris-setosa
# 5.2                                    1.5                  0.1  Iris-setosa
# 5.5                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.5                  0.1  Iris-setosa
# 5.0                                    1.2                  0.2  Iris-setosa
# 5.5                                    1.3                  0.2  Iris-setosa
# 4.9                                    1.5                  0.1  Iris-setosa
# 4.4                                    1.3                  0.2  Iris-setosa
# 5.1                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.3                  0.3  Iris-setosa
# 4.5                                    1.3                  0.3  Iris-setosa
# 4.4                                    1.3                  0.2  Iris-setosa
# 5.0                                    1.6                  0.6  Iris-setosa
# 5.1                                    1.9                  0.4  Iris-setosa
# 4.8                                    1.4                  0.3  Iris-setosa
# 5.1                                    1.6                  0.2  Iris-setosa
# 4.6                                    1.4                  0.2  Iris-setosa
# 5.3                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra']=iris['Sepal Length (in cm)']+ iris['Sepal Width in (cm)']

# %%
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class  \
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa
#
#                       SepalExtra
# Sepal Length (in cm)
# 5.1                          8.6
# 4.9                          7.9
# 4.7                          7.9
# 4.6                          7.7
# 5.0                          8.6

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.mean(axis=0)
# Out:
# (Sepal Length (in cm)    5.843333
#  Sepal Width in (cm)     3.054000
#  Petal length (in cm)    3.758667
#  Petal width (in cm)     1.198667
#  SepalExtra              8.897333
#  dtype: float64, Sepal Length (in cm)    0.685694
#  Sepal Width in (cm)     0.188004
#  Petal length (in cm)    3.113179
#  Petal width (in cm)     0.582414
#  SepalExtra              0.795161
#  dtype: float64)

# %%
iris.var(axis=0)
# Out:
# Sepal Length (in cm)    0.685694
# Sepal Width in (cm)     0.188004
# Petal length (in cm)    3.113179
# Petal width (in cm)     0.582414
# SepalExtra              0.795161
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def twonum (a,b):
    return a,b
a=iris.iloc[(4,0)]
b=iris.iloc[(4,1)]
twonum(a,b)
# Out:
# (5.0, 3.6)

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
print("range Sepal length in cm =", iris['Sepal Length (in cm)'].max() - iris['Sepal Length (in cm)'].min())
print("range Sepal Width in cm  =", iris['Sepal Width in (cm)'].max() - iris['Sepal Width in (cm)'].min())
print("range Petal length in cm =", iris['Petal length (in cm)'].max() - iris['Petal length (in cm)'].min())
print("range Petal width in cm  =", iris['Petal width (in cm)'].max() - iris['Petal width (in cm)'].min())
# Out:
# range Sepal length in cm = 3.6000000000000005
# range Sepal Width in cm  = 2.4000000000000004
# range Petal length in cm = 5.9
# range Petal width in cm  = 2.4

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_values(by=['Petal width (in cm)'])
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.2                                    5.2                  4.1
# 4.3                                    4.3                  3.0
# 4.9                                    4.9                  3.1
# 4.9                                    4.9                  3.1
# 4.8                                    4.8                  3.0
# 4.9                                    4.9                  3.1
# 5.1                                    5.1                  3.5
# 5.2                                    5.2                  3.5
# 5.2                                    5.2                  3.4
# 4.7                                    4.7                  3.2
# 4.8                                    4.8                  3.1
# 5.5                                    5.5                  4.2
# 5.5                                    5.5                  3.5
# 4.4                                    4.4                  3.0
# 5.1                                    5.1                  3.4
# 4.4                                    4.4                  3.2
# 5.1                                    5.1                  3.8
# 4.6                                    4.6                  3.2
# 5.3                                    5.3                  3.7
# 5.0                                    5.0                  3.3
# 5.0                                    5.0                  3.0
# 4.8                                    4.8                  3.4
# 5.0                                    5.0                  3.2
# 4.6                                    4.6                  3.1
# 4.7                                    4.7                  3.2
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 5.4                                    5.4                  3.7
# 5.0                                    5.0                  3.6
# 4.8                                    4.8                  3.4
# ...                                    ...                  ...
# 6.4                                    6.4                  2.7
# 5.6                                    5.6                  2.8
# 7.7                                    7.7                  2.8
# 6.5                                    6.5                  3.0
# 5.7                                    5.7                  2.5
# 7.9                                    7.9                  3.8
# 6.5                                    6.5                  3.2
# 6.9                                    6.9                  3.1
# 7.1                                    7.1                  3.0
# 6.8                                    6.8                  3.0
# 7.6                                    7.6                  3.0
# 6.7                                    6.7                  3.3
# 6.4                                    6.4                  2.8
# 7.7                                    7.7                  3.8
# 6.4                                    6.4                  2.8
# 6.5                                    6.5                  3.0
# 6.9                                    6.9                  3.2
# 6.4                                    6.4                  3.2
# 6.2                                    6.2                  3.4
# 6.9                                    6.9                  3.1
# 6.8                                    6.8                  3.2
# 6.7                                    6.7                  3.0
# 7.7                                    7.7                  2.6
# 7.7                                    7.7                  3.0
# 6.3                                    6.3                  3.4
# 6.7                                    6.7                  3.1
# 5.8                                    5.8                  2.8
# 6.3                                    6.3                  3.3
# 6.7                                    6.7                  3.3
# 7.2                                    7.2                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)  \
# Sepal Length (in cm)
# 5.2                                    1.5                  0.1
# 4.3                                    1.1                  0.1
# 4.9                                    1.5                  0.1
# 4.9                                    1.5                  0.1
# 4.8                                    1.4                  0.1
# 4.9                                    1.5                  0.1
# 5.1                                    1.4                  0.2
# 5.2                                    1.5                  0.2
# 5.2                                    1.4                  0.2
# 4.7                                    1.6                  0.2
# 4.8                                    1.6                  0.2
# 5.5                                    1.4                  0.2
# 5.5                                    1.3                  0.2
# 4.4                                    1.3                  0.2
# 5.1                                    1.5                  0.2
# 4.4                                    1.3                  0.2
# 5.1                                    1.6                  0.2
# 4.6                                    1.4                  0.2
# 5.3                                    1.5                  0.2
# 5.0                                    1.4                  0.2
# 5.0                                    1.6                  0.2
# 4.8                                    1.9                  0.2
# 5.0                                    1.2                  0.2
# 4.6                                    1.5                  0.2
# 4.7                                    1.3                  0.2
# 5.0                                    1.5                  0.2
# 4.4                                    1.4                  0.2
# 5.4                                    1.5                  0.2
# 5.0                                    1.4                  0.2
# 4.8                                    1.6                  0.2
# ...                                    ...                  ...
# 6.4                                    5.3                  1.9
# 5.6                                    4.9                  2.0
# 7.7                                    6.7                  2.0
# 6.5                                    5.2                  2.0
# 5.7                                    5.0                  2.0
# 7.9                                    6.4                  2.0
# 6.5                                    5.1                  2.0
# 6.9                                    5.4                  2.1
# 7.1                                    5.9                  2.1
# 6.8                                    5.5                  2.1
# 7.6                                    6.6                  2.1
# 6.7                                    5.7                  2.1
# 6.4                                    5.6                  2.1
# 7.7                                    6.7                  2.2
# 6.4                                    5.6                  2.2
# 6.5                                    5.8                  2.2
# 6.9                                    5.7                  2.3
# 6.4                                    5.3                  2.3
# 6.2                                    5.4                  2.3
# 6.9                                    5.1                  2.3
# 6.8                                    5.9                  2.3
# 6.7                                    5.2                  2.3
# 7.7                                    6.9                  2.3
# 7.7                                    6.1                  2.3
# 6.3                                    5.6                  2.4
# 6.7                                    5.6                  2.4
# 5.8                                    5.1                  2.4
# 6.3                                    6.0                  2.5
# 6.7                                    5.7                  2.5
# 7.2                                    6.1                  2.5
#
#                                Class  SepalExtra
# Sepal Length (in cm)
# 5.2                      Iris-setosa         9.3
# 4.3                      Iris-setosa         7.3
# 4.9                      Iris-setosa         8.0
# 4.9                      Iris-setosa         8.0
# 4.8                      Iris-setosa         7.8
# 4.9                      Iris-setosa         8.0
# 5.1                      Iris-setosa         8.6
# 5.2                      Iris-setosa         8.7
# 5.2                      Iris-setosa         8.6
# 4.7                      Iris-setosa         7.9
# 4.8                      Iris-setosa         7.9
# 5.5                      Iris-setosa         9.7
# 5.5                      Iris-setosa         9.0
# 4.4                      Iris-setosa         7.4
# 5.1                      Iris-setosa         8.5
# 4.4                      Iris-setosa         7.6
# 5.1                      Iris-setosa         8.9
# 4.6                      Iris-setosa         7.8
# 5.3                      Iris-setosa         9.0
# 5.0                      Iris-setosa         8.3
# 5.0                      Iris-setosa         8.0
# 4.8                      Iris-setosa         8.2
# 5.0                      Iris-setosa         8.2
# 4.6                      Iris-setosa         7.7
# 4.7                      Iris-setosa         7.9
# 5.0                      Iris-setosa         8.4
# 4.4                      Iris-setosa         7.3
# 5.4                      Iris-setosa         9.1
# 5.0                      Iris-setosa         8.6
# 4.8                      Iris-setosa         8.2
# ...                              ...         ...
# 6.4                   Iris-virginica         9.1
# 5.6                   Iris-virginica         8.4
# 7.7                   Iris-virginica        10.5
# 6.5                   Iris-virginica         9.5
# 5.7                   Iris-virginica         8.2
# 7.9                   Iris-virginica        11.7
# 6.5                   Iris-virginica         9.7
# 6.9                   Iris-virginica        10.0
# 7.1                   Iris-virginica        10.1
# 6.8                   Iris-virginica         9.8
# 7.6                   Iris-virginica        10.6
# 6.7                   Iris-virginica        10.0
# 6.4                   Iris-virginica         9.2
# 7.7                   Iris-virginica        11.5
# 6.4                   Iris-virginica         9.2
# 6.5                   Iris-virginica         9.5
# 6.9                   Iris-virginica        10.1
# 6.4                   Iris-virginica         9.6
# 6.2                   Iris-virginica         9.6
# 6.9                   Iris-virginica        10.0
# 6.8                   Iris-virginica        10.0
# 6.7                   Iris-virginica         9.7
# 7.7                   Iris-virginica        10.3
# 7.7                   Iris-virginica        10.7
# 6.3                   Iris-virginica         9.7
# 6.7                   Iris-virginica         9.8
# 5.8                   Iris-virginica         8.6
# 6.3                   Iris-virginica         9.6
# 6.7                   Iris-virginica        10.0
# 7.2                   Iris-virginica        10.8
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop(['SepalExtra'], inplace=True,axis=1,errors='ignore')

# %%
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=iris.iloc[0:10,0:3]

# %%
IrisSubset.head(10)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
#
#                       Petal length (in cm)
# Sepal Length (in cm)
# 5.1                                    1.4
# 4.9                                    1.4
# 4.7                                    1.3
# 4.6                                    1.5
# 5.0                                    1.4
# 5.4                                    1.7
# 4.6                                    1.4
# 5.0                                    1.5
# 4.4                                    1.4
# 4.9                                    1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HRexternal = pd.read_csv('HR_external-1.txt', delimiter="\t")
HRexternal.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                 1          2               1              1
# 1                 8          1               1              1
# 2                 2          2               6              1
# 3                 3          4               1              1
# 4                 2          1               2              1
#
#            ...           RelationshipSatisfaction  StandardHours  \
# 0          ...                                  1             80
# 1          ...                                  4             80
# 2          ...                                  2             80
# 3          ...                                  3             80
# 4          ...                                  4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
HRexternal.shape
# Out:
# (1470, 35)

# %%
print("Number of Rows, Columns =", HRexternal.shape)
# Out:
# Number of Rows, Columns = (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HRexternal.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HRexternal.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# ...              ...            ...
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
Female = HRexternal[HRexternal["Gender"]==2].count()["Gender"]
Male = HRexternal[HRexternal["Gender"]==1].count()["Gender"]

# %%
print ("Count of Male   =",(Male))
print ("Count of Female =",(Female))
# Out:
# Count of Male   = 882
# Count of Female = 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
# find the IQR for the column Age from dataframe HRexternal
HRexternal.sort_values(by=["Age"])
Q1=HRexternal["Age"].quantile(0.25)
Q3=HRexternal["Age"].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
HRexternal['DailyRate'].mean(), HRexternal['DailyRate'].median(), HRexternal['DailyRate'].var()
# Out:
# (802.4857142857143, 802.0, 162819.59373723628)

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
yes = HRexternal[HRexternal["Attrition"]=="Yes"].count()["Attrition"]
no = HRexternal[HRexternal["Attrition"]=="No"].count()["Attrition"] 
print ("Count of yes",(yes))
print ("Count of no",(no))
HRexternal['Attrition'].value_counts()

HRexternal["Attrition"].value_counts().plot(kind='barh')
# Out:
# Count of yes 237
# Count of no 1233

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
TWY = HRexternal.groupby('JobLevel')['TotalWorkingYears'].mean().sort_values()
TWY.plot(kind='barh', figsize=(4, 5), color='Blue', zorder=2, width=0.5)
